# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats
import statsmodels.api as sm

# %%
# read in data
frag_data = pd.read_csv('./data/fra_cleaned.csv')

frag_data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[51], line 2
#       1 # read in data
# ----> 2 frag_data = pd.read_csv('./data/fra_cleaned.csv')
#       4 frag_data
#
# File c:\Users\17782\fragrance-finder\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\17782\fragrance-finder\venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\17782\fragrance-finder\venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\17782\fragrance-finder\venv\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\17782\fragrance-finder\venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 24136: invalid continuation byte

# %%
# # read in data with explicit encoding to handle special characters
# frag_data = pd.read_csv('./data/fra_cleaned.csv', encoding='latin-1')

# # alternatively, try these encodings if latin-1 doesn't work:
# # frag_data = pd.read_csv('./data/fra_cleaned.csv', encoding='iso-8859-1') 
# # frag_data = pd.read_csv('./data/fra_cleaned.csv', encoding='cp1252')

# Try reading with a different delimiter and error handling
frag_data = pd.read_csv('./data/fra_cleaned.csv', 
                        encoding='latin-1',
                        sep=None, # Let pandas detect the separator
                        engine='python', # More flexible but slower engine
                        on_bad_lines='skip') # Warn about skipped rows

# Display info about the dataframe structure
print("\nDataframe Info:")
print(frag_data.info())

# Display first few rows to check parsing
print("\nFirst few rows:")
print(frag_data.head())
# Out:
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24063 entries, 0 to 24062
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           24063 non-null  object
#  1   Perfume       24063 non-null  object
#  2   Brand         24063 non-null  object
#  3   Country       24063 non-null  object
#  4   Gender        24063 non-null  object
#  5   Rating Value  24063 non-null  object
#  6   Rating Count  24063 non-null  int64
#  7   Year          22026 non-null  float64
#  8   Top           24063 non-null  object
#  9   Middle        24063 non-null  object
#  10  Base          24063 non-null  object
#  11  Perfumer1     24063 non-null  object
#  12  Perfumer2     1336 non-null   object
#  13  mainaccord1   24063 non-null  object
#  14  mainaccord2   24050 non-null  object
#  15  mainaccord3   23949 non-null  object
#  16  mainaccord4   23675 non-null  object
#  17  mainaccord5   23082 non-null  object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 3.3+ MB
# None
#
# First few rows:
#                                                  url  \
# 0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1  https://www.fragrantica.com/perfume/jean-paul-...
# 2  https://www.fragrantica.com/perfume/jean-paul-...
# 3  https://www.fragrantica.com/perfume/bruno-bana...
# 4  https://www.fragrantica.com/perfume/jean-paul-...
#
#                           Perfume               Brand  Country  Gender  \
# 0  accento-overdose-pride-edition             xerjoff    Italy  unisex
# 1            classique-pride-2024  jean-paul-gaultier   France   women
# 2            classique-pride-2023  jean-paul-gaultier   France  unisex
# 3               pride-edition-man        bruno-banani  Germany     men
# 4         le-male-pride-collector  jean-paul-gaultier   France     men
#
#   Rating Value  Rating Count    Year  \
# 0         1,42           201  2022.0
# 1         1,86            70  2024.0
# 2         1,91           285  2023.0
# 3         1,92            59  2019.0
# 4         1,93           632  2020.0
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                                 yuzu, citruses
# 2                             blood orange, yuzu
# 3                 guarana, grapefruit, red apple
# 4  mint, lavender, cardamom, artemisia, bergamot
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             orange blossom, neroli
# 2                             neroli, orange blossom
# 3                            walnut, lavender, guava
# 4                  caraway, cinnamon, orange blossom
#
#                                             Base             Perfumer1  \
# 0                               eucalyptus, pine               unknown
# 1                             musk, blonde woods               unknown
# 2                              musk, white woods  natalie gracia-cetto
# 3                        vetiver, benzoin, amber               unknown
# 4  vanilla, sandalwood, amber, cedar, tonka bean     francis kurkdjian
#
#        Perfumer2 mainaccord1   mainaccord2  mainaccord3  mainaccord4  \
# 0            NaN        rose         woody       fruity     aromatic
# 1            NaN      citrus  white floral        sweet        fresh
# 2  quentin bisch      citrus  white floral        sweet  fresh spicy
# 3            NaN      fruity         nutty        woody     tropical
# 4            NaN    aromatic    warm spicy  fresh spicy     cinnamon
#
#   mainaccord5
# 0      floral
# 1       musky
# 2       musky
# 3         NaN
# 4     vanilla

# %%
frag_data
# Out:
#                                                      url  \
# 0      https://www.fragrantica.com/perfume/xerjoff/ac...
# 1      https://www.fragrantica.com/perfume/jean-paul-...
# 2      https://www.fragrantica.com/perfume/jean-paul-...
# 3      https://www.fragrantica.com/perfume/bruno-bana...
# 4      https://www.fragrantica.com/perfume/jean-paul-...
# ...                                                  ...
# 24058  https://www.fragrantica.com/perfume/o-boticari...
# 24059  https://www.fragrantica.com/perfume/sultan-pas...
# 24060  https://www.fragrantica.com/perfume/darkbeat-p...
# 24061  https://www.fragrantica.com/perfume/parfumerie...
# 24062  https://www.fragrantica.com/perfume/nilafar-du...
#
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# 2                classique-pride-2023   jean-paul-gaultier   France  unisex
# 3                   pride-edition-man         bruno-banani  Germany     men
# 4             le-male-pride-collector   jean-paul-gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o-boticario   Brazil   women
# 24059                 cheval-d-arabie  sultan-pasha-attars       UK  unisex
# 24060                           khaox     darkbeat-parfums    Spain  unisex
# 24061                       aoud-no-1  parfumerie-bruckner  Germany  unisex
# 24062        narmar-extrait-de-parfum       nilafar-du-nil    Egypt     men
#
#       Rating Value  Rating Count    Year  \
# 0             1,42           201  2022.0
# 1             1,86            70  2024.0
# 2             1,91           285  2023.0
# 3             1,92            59  2019.0
# 4             1,93           632  2020.0
# ...            ...           ...     ...
# 24058         4,81            31  1992.0
# 24059         4,81            26  2020.0
# 24060         4,85            26  2020.0
# 24061         4,86            28  2011.0
# 24062         4,93            30  2022.0
#
#                                                      Top  \
# 0                   fruity notes, aldehydes, green notes
# 1                                         yuzu, citruses
# 2                                     blood orange, yuzu
# 3                         guarana, grapefruit, red apple
# 4          mint, lavender, cardamom, artemisia, bergamot
# ...                                                  ...
# 24058                                ozonic notes, peach
# 24059  taif rose, indian oud, white rose, olibanum, e...
# 24060                                    mint, lime, rum
# 24061                              apple, peach, saffron
# 24062  cardamom, lavender, juniper, bergamot, clary sage
#
#                                                   Middle  \
# 0      bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                                 orange blossom, neroli
# 2                                 neroli, orange blossom
# 3                                walnut, lavender, guava
# 4                      caraway, cinnamon, orange blossom
# ...                                                  ...
# 24058                        lily-of-the-valley, jasmine
# 24059  bulgarian rose, indian oud, hay, leather, cive...
# 24060             lily-of-the-valley, fig leaf, cardamom
# 24061                      plum, orange blossom, jasmine
# 24062         cashmeran, rose, green tea, lily, cinnamon
#
#                                                     Base  \
# 0                                       eucalyptus, pine
# 1                                     musk, blonde woods
# 2                                      musk, white woods
# 3                                vetiver, benzoin, amber
# 4          vanilla, sandalwood, amber, cedar, tonka bean
# ...                                                  ...
# 24058                                        musk, amber
# 24059  white amber, leather, hay, elemi resin, kyara ...
# 24060                    musk, oakmoss, amber, patchouli
# 24061                agarwood (oud), sandalwood, vanilla
# 24062  cashmeran, tobacco, oakmoss, suede, tonka bean...
#
#                   Perfumer1      Perfumer2   mainaccord1   mainaccord2  \
# 0                   unknown            NaN          rose         woody
# 1                   unknown            NaN        citrus  white floral
# 2      natalie gracia-cetto  quentin bisch        citrus  white floral
# 3                   unknown            NaN        fruity         nutty
# 4         francis kurkdjian            NaN      aromatic    warm spicy
# ...                     ...            ...           ...           ...
# 24058       thierry lecoule            NaN  white floral        ozonic
# 24059          sultan pasha            NaN          rose         amber
# 24060       josé m. giraldo            NaN         green      aromatic
# 24061               unknown            NaN        fruity         sweet
# 24062               unknown            NaN      aromatic         woody
#
#        mainaccord3  mainaccord4  mainaccord5
# 0           fruity     aromatic       floral
# 1            sweet        fresh        musky
# 2            sweet  fresh spicy        musky
# 3            woody     tropical          NaN
# 4      fresh spicy     cinnamon      vanilla
# ...            ...          ...          ...
# 24058        fresh        musky      powdery
# 24059  fresh spicy     animalic     aromatic
# 24060       citrus  fresh spicy        woody
# 24061          oud        woody      powdery
# 24062   warm spicy        musky  fresh spicy
#
# [24063 rows x 18 columns]

# %%
# list all columns
frag_data.columns
# Out:
# Index(['url', 'Perfume', 'Brand', 'Country', 'Gender', 'Rating Value',
#        'Rating Count', 'Year', 'Top', 'Middle', 'Base', 'Perfumer1',
#        'Perfumer2', 'mainaccord1', 'mainaccord2', 'mainaccord3', 'mainaccord4',
#        'mainaccord5'],
#       dtype='object')

# %%
# drop url Perfumer1 Perfumer2
frag_data_selected = frag_data.drop(columns=['url', 'Perfumer1', 'Perfumer2'])
frag_data_selected
# Out:
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# 2                classique-pride-2023   jean-paul-gaultier   France  unisex
# 3                   pride-edition-man         bruno-banani  Germany     men
# 4             le-male-pride-collector   jean-paul-gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o-boticario   Brazil   women
# 24059                 cheval-d-arabie  sultan-pasha-attars       UK  unisex
# 24060                           khaox     darkbeat-parfums    Spain  unisex
# 24061                       aoud-no-1  parfumerie-bruckner  Germany  unisex
# 24062        narmar-extrait-de-parfum       nilafar-du-nil    Egypt     men
#
#       Rating Value  Rating Count    Year  \
# 0             1,42           201  2022.0
# 1             1,86            70  2024.0
# 2             1,91           285  2023.0
# 3             1,92            59  2019.0
# 4             1,93           632  2020.0
# ...            ...           ...     ...
# 24058         4,81            31  1992.0
# 24059         4,81            26  2020.0
# 24060         4,85            26  2020.0
# 24061         4,86            28  2011.0
# 24062         4,93            30  2022.0
#
#                                                      Top  \
# 0                   fruity notes, aldehydes, green notes
# 1                                         yuzu, citruses
# 2                                     blood orange, yuzu
# 3                         guarana, grapefruit, red apple
# 4          mint, lavender, cardamom, artemisia, bergamot
# ...                                                  ...
# 24058                                ozonic notes, peach
# 24059  taif rose, indian oud, white rose, olibanum, e...
# 24060                                    mint, lime, rum
# 24061                              apple, peach, saffron
# 24062  cardamom, lavender, juniper, bergamot, clary sage
#
#                                                   Middle  \
# 0      bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                                 orange blossom, neroli
# 2                                 neroli, orange blossom
# 3                                walnut, lavender, guava
# 4                      caraway, cinnamon, orange blossom
# ...                                                  ...
# 24058                        lily-of-the-valley, jasmine
# 24059  bulgarian rose, indian oud, hay, leather, cive...
# 24060             lily-of-the-valley, fig leaf, cardamom
# 24061                      plum, orange blossom, jasmine
# 24062         cashmeran, rose, green tea, lily, cinnamon
#
#                                                     Base   mainaccord1  \
# 0                                       eucalyptus, pine          rose
# 1                                     musk, blonde woods        citrus
# 2                                      musk, white woods        citrus
# 3                                vetiver, benzoin, amber        fruity
# 4          vanilla, sandalwood, amber, cedar, tonka bean      aromatic
# ...                                                  ...           ...
# 24058                                        musk, amber  white floral
# 24059  white amber, leather, hay, elemi resin, kyara ...          rose
# 24060                    musk, oakmoss, amber, patchouli         green
# 24061                agarwood (oud), sandalwood, vanilla        fruity
# 24062  cashmeran, tobacco, oakmoss, suede, tonka bean...      aromatic
#
#         mainaccord2  mainaccord3  mainaccord4  mainaccord5
# 0             woody       fruity     aromatic       floral
# 1      white floral        sweet        fresh        musky
# 2      white floral        sweet  fresh spicy        musky
# 3             nutty        woody     tropical          NaN
# 4        warm spicy  fresh spicy     cinnamon      vanilla
# ...             ...          ...          ...          ...
# 24058        ozonic        fresh        musky      powdery
# 24059         amber  fresh spicy     animalic     aromatic
# 24060      aromatic       citrus  fresh spicy        woody
# 24061         sweet          oud        woody      powdery
# 24062         woody   warm spicy        musky  fresh spicy
#
# [24063 rows x 15 columns]

# %%
# in Rating Value column replace , with .
frag_data_selected['Rating Value'] = frag_data_selected['Rating Value'].str.replace(',', '.')
frag_data_selected
# Out:
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# 2                classique-pride-2023   jean-paul-gaultier   France  unisex
# 3                   pride-edition-man         bruno-banani  Germany     men
# 4             le-male-pride-collector   jean-paul-gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o-boticario   Brazil   women
# 24059                 cheval-d-arabie  sultan-pasha-attars       UK  unisex
# 24060                           khaox     darkbeat-parfums    Spain  unisex
# 24061                       aoud-no-1  parfumerie-bruckner  Germany  unisex
# 24062        narmar-extrait-de-parfum       nilafar-du-nil    Egypt     men
#
#       Rating Value  Rating Count    Year  \
# 0             1.42           201  2022.0
# 1             1.86            70  2024.0
# 2             1.91           285  2023.0
# 3             1.92            59  2019.0
# 4             1.93           632  2020.0
# ...            ...           ...     ...
# 24058         4.81            31  1992.0
# 24059         4.81            26  2020.0
# 24060         4.85            26  2020.0
# 24061         4.86            28  2011.0
# 24062         4.93            30  2022.0
#
#                                                      Top  \
# 0                   fruity notes, aldehydes, green notes
# 1                                         yuzu, citruses
# 2                                     blood orange, yuzu
# 3                         guarana, grapefruit, red apple
# 4          mint, lavender, cardamom, artemisia, bergamot
# ...                                                  ...
# 24058                                ozonic notes, peach
# 24059  taif rose, indian oud, white rose, olibanum, e...
# 24060                                    mint, lime, rum
# 24061                              apple, peach, saffron
# 24062  cardamom, lavender, juniper, bergamot, clary sage
#
#                                                   Middle  \
# 0      bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                                 orange blossom, neroli
# 2                                 neroli, orange blossom
# 3                                walnut, lavender, guava
# 4                      caraway, cinnamon, orange blossom
# ...                                                  ...
# 24058                        lily-of-the-valley, jasmine
# 24059  bulgarian rose, indian oud, hay, leather, cive...
# 24060             lily-of-the-valley, fig leaf, cardamom
# 24061                      plum, orange blossom, jasmine
# 24062         cashmeran, rose, green tea, lily, cinnamon
#
#                                                     Base   mainaccord1  \
# 0                                       eucalyptus, pine          rose
# 1                                     musk, blonde woods        citrus
# 2                                      musk, white woods        citrus
# 3                                vetiver, benzoin, amber        fruity
# 4          vanilla, sandalwood, amber, cedar, tonka bean      aromatic
# ...                                                  ...           ...
# 24058                                        musk, amber  white floral
# 24059  white amber, leather, hay, elemi resin, kyara ...          rose
# 24060                    musk, oakmoss, amber, patchouli         green
# 24061                agarwood (oud), sandalwood, vanilla        fruity
# 24062  cashmeran, tobacco, oakmoss, suede, tonka bean...      aromatic
#
#         mainaccord2  mainaccord3  mainaccord4  mainaccord5
# 0             woody       fruity     aromatic       floral
# 1      white floral        sweet        fresh        musky
# 2      white floral        sweet  fresh spicy        musky
# 3             nutty        woody     tropical          NaN
# 4        warm spicy  fresh spicy     cinnamon      vanilla
# ...             ...          ...          ...          ...
# 24058        ozonic        fresh        musky      powdery
# 24059         amber  fresh spicy     animalic     aromatic
# 24060      aromatic       citrus  fresh spicy        woody
# 24061         sweet          oud        woody      powdery
# 24062         woody   warm spicy        musky  fresh spicy
#
# [24063 rows x 15 columns]

# %%
# combine Perfume and Brand columns with "by"
frag_data_selected['full_perfume_name'] = frag_data_selected['Perfume'] + ' by ' + frag_data_selected['Brand']
frag_data_selected

# drop Brand column
frag_data_selected = frag_data_selected.drop(columns=['Brand'])
frag_data_selected

# drop Perfume column
frag_data_selected = frag_data_selected.drop(columns=['Perfume'])
frag_data_selected

# drop Gender column
frag_data_selected = frag_data_selected.drop(columns=['Gender'])
frag_data_selected
# Out:
#        Country Rating Value  Rating Count    Year  \
# 0        Italy         1.42           201  2022.0
# 1       France         1.86            70  2024.0
# 2       France         1.91           285  2023.0
# 3      Germany         1.92            59  2019.0
# 4       France         1.93           632  2020.0
# ...        ...          ...           ...     ...
# 24058   Brazil         4.81            31  1992.0
# 24059       UK         4.81            26  2020.0
# 24060    Spain         4.85            26  2020.0
# 24061  Germany         4.86            28  2011.0
# 24062    Egypt         4.93            30  2022.0
#
#                                                      Top  \
# 0                   fruity notes, aldehydes, green notes
# 1                                         yuzu, citruses
# 2                                     blood orange, yuzu
# 3                         guarana, grapefruit, red apple
# 4          mint, lavender, cardamom, artemisia, bergamot
# ...                                                  ...
# 24058                                ozonic notes, peach
# 24059  taif rose, indian oud, white rose, olibanum, e...
# 24060                                    mint, lime, rum
# 24061                              apple, peach, saffron
# 24062  cardamom, lavender, juniper, bergamot, clary sage
#
#                                                   Middle  \
# 0      bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                                 orange blossom, neroli
# 2                                 neroli, orange blossom
# 3                                walnut, lavender, guava
# 4                      caraway, cinnamon, orange blossom
# ...                                                  ...
# 24058                        lily-of-the-valley, jasmine
# 24059  bulgarian rose, indian oud, hay, leather, cive...
# 24060             lily-of-the-valley, fig leaf, cardamom
# 24061                      plum, orange blossom, jasmine
# 24062         cashmeran, rose, green tea, lily, cinnamon
#
#                                                     Base   mainaccord1  \
# 0                                       eucalyptus, pine          rose
# 1                                     musk, blonde woods        citrus
# 2                                      musk, white woods        citrus
# 3                                vetiver, benzoin, amber        fruity
# 4          vanilla, sandalwood, amber, cedar, tonka bean      aromatic
# ...                                                  ...           ...
# 24058                                        musk, amber  white floral
# 24059  white amber, leather, hay, elemi resin, kyara ...          rose
# 24060                    musk, oakmoss, amber, patchouli         green
# 24061                agarwood (oud), sandalwood, vanilla        fruity
# 24062  cashmeran, tobacco, oakmoss, suede, tonka bean...      aromatic
#
#         mainaccord2  mainaccord3  mainaccord4  mainaccord5  \
# 0             woody       fruity     aromatic       floral
# 1      white floral        sweet        fresh        musky
# 2      white floral        sweet  fresh spicy        musky
# 3             nutty        woody     tropical          NaN
# 4        warm spicy  fresh spicy     cinnamon      vanilla
# ...             ...          ...          ...          ...
# 24058        ozonic        fresh        musky      powdery
# 24059         amber  fresh spicy     animalic     aromatic
# 24060      aromatic       citrus  fresh spicy        woody
# 24061         sweet          oud        woody      powdery
# 24062         woody   warm spicy        musky  fresh spicy
#
#                                    full_perfume_name
# 0          accento-overdose-pride-edition by xerjoff
# 1         classique-pride-2024 by jean-paul-gaultier
# 2         classique-pride-2023 by jean-paul-gaultier
# 3                  pride-edition-man by bruno-banani
# 4      le-male-pride-collector by jean-paul-gaultier
# ...                                              ...
# 24058                        floratta by o-boticario
# 24059         cheval-d-arabie by sultan-pasha-attars
# 24060                      khaox by darkbeat-parfums
# 24061               aoud-no-1 by parfumerie-bruckner
# 24062     narmar-extrait-de-parfum by nilafar-du-nil
#
# [24063 rows x 13 columns]
